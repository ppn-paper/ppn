# %%
from exp_utils import *

shape,figsize=(1,3),5
showSamples(showtest=False, shape=shape,size=figsize)  # reconstruct result
showSamples(showtest=True, shape=shape,size=figsize)
# Out:
# /home/uqwjian7/workspace/ppn_isbi/working/sampling/samples#64_x8_step1000_psnr_36.1020_1.5067_ssim_0.9155_0.0147_rmse_0.0159_0.0026.nii
# shape:  (8, 320, 320) (1, 3)
# 64_x8_step1000_psnr_36.1020_1.5067_ssim_0.9155_0.0147_rmse_0.0159_0.0026.nii
# /home/uqwjian7/workspace/ppn_isbi/working/sampling/testset.nii
# shape:  (8, 320, 320) (1, 3)
